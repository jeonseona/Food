# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# 데이터셋 로드
food = pd.read_csv('./foodData4_24.csv')
user_data = pd.read_csv('./123456.csv')    # 유저 데이터셋 예시

# 결측값 처리(Keywords열의 데이터 중 nan값 공백으로 처리)
# 현재 food 데이터에 일부 깨진데이터(?)가 있어서 결측값 처리해야 정상작동
food['Keywords'] = food['Keywords'].fillna('')

# TF-IDF(Term Frequency-Inverse Document Frequency)
# 텍스트 데이터의 통계적인 가중치를 계산, 처리해주는 기능(자연어 처리)

# TfidfVectorizer : 문서를 벡터 표현으로 바꿔주는 기능
# stop_words='english' => 영어의 일반적인 불용어 삭제(and, is, the, this 등 단어와 상관없는 문자)
tfidf = TfidfVectorizer(stop_words='english')

# food의 Keywords를 단어로 구별
# 단어로 구별된 Keywords를 TF-IDF 행렬로 생성
tfidf_matrix = tfidf.fit_transform(food['Keywords'])

# 사용자 정보를 담을 빈 딕셔너리 생성
users = {}

# 데이터프레임 순회
for index, row in user_data.iterrows():
    # 각 유저의 정보 추출
    user_name = row['이름']
    user_height = row['키']
    user_weight = row['몸무게']
    user_gender = row['성별']
    user_keywords = row['키워드']

    # BMI 계산
    height_m = user_height / 100
    weight_kg = user_weight
    bmi = weight_kg / (height_m ** 2)

    # 추정된 칼로리 요구량 계산
    if user_gender == '남':
        bmr = 88.362 + (13.397 * weight_kg) + (4.799 * height_m * 100) - (5.677 * 33)
    else:
        bmr = 447.593 + (9.247 * weight_kg) + (3.098 * height_m * 100) - (4.330 * 33)

    calories_threshold = bmr * 1.2

    # 사용자 정보를 딕셔너리에 추가
    # 사용자의 TF-IDF 행렬을 구성합니다.
    user_tfidf_matrix = tfidf.transform([user_keywords])
    users[user_name] = {'Keywords': user_keywords, 'Calories_threshold': calories_threshold, 'TFIDF_matrix': user_tfidf_matrix}

# 추천 함수 정의
def get_recommendations_break(user_keywords, user_tfidf_matrix, tfidf_matrix, food_data, calories_threshold):
    # 사용자 키워드 행렬과 food 데이터의 키워드 행렬의 코사인 유사도 계산
    cosine_sim = cosine_similarity(user_tfidf_matrix, tfidf_matrix)
   
    # 코사인 유사도가 계산되었으므로, 유사도가 높은 상위 음식을 추천 리스트에 추가합니다.
    # 유사도를 기준으로 내림차순으로 정렬하여 상위 음식을 추천 리스트에 추가합니다.
    sim_scores = list(enumerate(cosine_sim[0]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # 상위 음식을 추천 리스트에 추가합니다.
    recommended_food_break = []
   
    for index, score in sim_scores:
        food_name = food_data.iloc[index]['Name']
        food_calories = food_data.iloc[index]['Calories']
        if food_calories <= calories_threshold * 0.1:
            recommended_food_break.append({'Name': food_name, 'Calories': food_calories}) 
    
    return recommended_food_break

def get_recommendations_lunch(user_keywords, user_tfidf_matrix, tfidf_matrix, food_data, calories_threshold):
    # 사용자 키워드 행렬과 food 데이터의 키워드 행렬의 코사인 유사도 계산
    cosine_sim = cosine_similarity(user_tfidf_matrix, tfidf_matrix)
   
    # 코사인 유사도가 계산되었으므로, 유사도가 높은 상위 음식을 추천 리스트에 추가합니다.
    # 유사도를 기준으로 내림차순으로 정렬하여 상위 음식을 추천 리스트에 추가합니다.
    sim_scores = list(enumerate(cosine_sim[0]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # 상위 음식을 추천 리스트에 추가합니다.
    recommended_food_lunch = []
   
    for index, score in sim_scores:
        food_name = food_data.iloc[index]['Name']
        food_calories = food_data.iloc[index]['Calories']
        if food_calories <= calories_threshold * 0.45:
            recommended_food_lunch.append({'Name': food_name, 'Calories': food_calories}) 
    
    return recommended_food_lunch

def get_recommendations_dinner(user_keywords, user_tfidf_matrix, tfidf_matrix, food_data, calories_threshold):
    # 사용자 키워드 행렬과 food 데이터의 키워드 행렬의 코사인 유사도 계산
    cosine_sim = cosine_similarity(user_tfidf_matrix, tfidf_matrix)
   
    # 코사인 유사도가 계산되었으므로, 유사도가 높은 상위 음식을 추천 리스트에 추가합니다.
    # 유사도를 기준으로 내림차순으로 정렬하여 상위 음식을 추천 리스트에 추가합니다.
    sim_scores = list(enumerate(cosine_sim[0]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # 상위 음식을 추천 리스트에 추가합니다.
    recommended_food_dinner = []
   
    for index, score in sim_scores:
        food_name = food_data.iloc[index]['Name']
        food_calories = food_data.iloc[index]['Calories']
        if food_calories <= calories_threshold * 0.15:
            recommended_food_dinner.append({'Name': food_name, 'Calories': food_calories}) 
    
    return recommended_food_dinner

# 결과 출력
for user_name, user_info in users.items():
    print(user_name, "님의 필터된 음식 추천:")
    print("아침메뉴 추천:", user_info['Calories_threshold']*0.1, "kcal 이내")
    recommendations_break = get_recommendations_break(user_info['Keywords'], user_info['TFIDF_matrix'], tfidf_matrix, food, user_info['Calories_threshold'])
    print(pd.DataFrame(recommendations_break[1:100000:1000]))

    print("점심메뉴 추천:", user_info['Calories_threshold']*0.45, "kcal 이내")
    recommendations_lunch = get_recommendations_lunch(user_info['Keywords'], user_info['TFIDF_matrix'], tfidf_matrix, food, user_info['Calories_threshold'])
    print(pd.DataFrame(recommendations_lunch[2:100000:1000]))

    print("저녁메뉴 추천:", user_info['Calories_threshold']*0.15, "kcal 이내")
    recommendations_dinner = get_recommendations_dinner(user_info['Keywords'], user_info['TFIDF_matrix'], tfidf_matrix, food, user_info['Calories_threshold'])
    print(pd.DataFrame(recommendations_dinner[3:100000:1000]))
# Out:
# 홍길동 님의 필터된 음식 추천:
# 아침메뉴 추천: 209.17216800000003 kcal 이내
#                                                  Name  Calories
# 0                       Bittersweet Chocolate Granita     178.3
# 1           Extract the Most Juice from Citrus Fruits      98.5
# 2                           Portobello Mushroom Toast      89.9
# 3                       Grilled Corn With Mint Butter     153.9
# 4                               Italian stuffed bread       0.0
# 5                          Lemon &amp; Coriander Soup      34.2
# 6                                 Vegan Lemon Cookies     190.0
# 7               Chocolate Blocks With Fruits and Nuts      66.4
# 8                                  Caramelized Onions     107.6
# 9                        Golden Autumn Soup (Low Fat)      60.6
# 10           Carrot &amp; Zucchini Ribbons With Pesto      45.2
# 11                                  Strawberry Squash     166.3
# 12                                    Jalapeno Butter     106.6
# 13                          Stiff Porridge (Oshifima)     177.1
# 14                              Banana Carrot Muffins      94.3
# 15                                Buttery Apple Crisp     166.3
# 16                           Mulled Wine a La Kolibri     163.4
# 17  Mushroom and Horseradish Hamburgers (Reduced Fat)     180.2
# 18                Garlic Tomatoes - for the Tapas Bar      79.8
# 19                                   Faux Wheat Thins      10.4
# 20  Allergy Friendly Fruit Muffins (Wheat, Egg, Da...     175.5
# 21                       Low Calorie Cheesy Asparagus      39.6
# 22                             Buttermilk Peach Slush      86.5
# 23                                    Candy Crescents      87.0
# 24                  Barbecued Sesame  Chicken Breasts     166.2
# 25                        Fresh Herb and Tomato Salad      54.9
# 26       Nalesniki - Polish Crepes With Apple Filling     109.3
# 27                       Mini Blackberry Cream Scones     167.5
# 28                                     Corn Tortillas       0.0
# 29                                   Butter-Nut Drops      49.9
# 30                                     Dolphin's Foam       0.0
# 31                  Crispy Fried Eggplant (Aubergine)      86.4
# 32                              Tomato cucumber salad      37.4
# 33                                     Arab Spice Mix     163.4
# 34                  Christmastini (Christmas Martini)      64.2
# 35                                    Boiled Pig Feet      82.1
# 36                                 Cream Cheese Sauce     137.2
# 37                         Ricotta -Spinach Casserole     208.4
# 38                                         Easter Egg      41.5
# 39                              Caramelized Onion Dip     179.8
# 40        Creamy Marshmallow Dip (From Cooking Light)      75.3
# 41                 Lime Sunset Non-Alcoholic Cocktail     111.3
# 42                   Whole Wheat Flax'n Apple Muffins     180.2
# 43                                         Irish Eggs     184.4
# 44                   Cheap, Clean Mirrors, No Streaks      50.2
# 45                                        Pizza Salad     192.9
# 46                                       French Toast     208.8
# 47                               Herbed Spinach Balls      19.2
# 48                            Healthy Apricot Cookies     100.8
# 49                             Chilled Mexican Coffee     111.3
# 50                  Chef Joey's Vegan Holiday Squares     152.9
# 51   Spaghetti Squash Casserole (South Beach Diet P1)     202.0
# 52                       Tamarind-Glazed Honey Shrimp     143.4
# 53      Bolludagur Buns - Icelandic Cream-Filled Buns     136.3
# 54                             Lively Lemon Gin Tonic     107.4
# 55                        Ground Beef Minestrone Soup     147.0
# 점심메뉴 추천: 941.274756 kcal 이내
#                                                 Name  Calories
# 0                            Simple Vanilla Ice Milk     176.3
# 1           Mightyro's Bok Choy-Leek-Noodle Stir Fry     568.6
# 2   Rice Noodles With Tahini Sauce and Mixed Veggies     576.1
# 3                              Cheesy Rumbledethumps     261.9
# 4          Amazing Vegetable Soup (South Beach Diet)      83.0
# ..                                               ...       ...
# 95              Peanut Butter Striped Chocolate Cake     219.8
# 96              Bust Your Lips Southern Baked Beans.     181.6
# 97                      Bacon &amp; Ricotta Stuffing     416.4
# 98                           Japanese Cucumber Salad      41.5
# 99                       No-Nonsense Chuck Eye Steak     122.2
#
# [100 rows x 2 columns]
# 저녁메뉴 추천: 313.758252 kcal 이내
#                                           Name  Calories
# 0                       Cranberry Cooler Slush     192.8
# 1                       Mango Black Bean Salsa      67.4
# 2                    Slow Cooker Peach Cobbler     190.6
# 3                       Swedish Cucumber Salad      99.5
# 4                   Glazed Carrots With Onions     124.8
# ..                                         ...       ...
# 82            Barley With Mushrooms (Scotland)     237.0
# 83                             Zanzibari Prawn     172.0
# 84           Italian Wedding Soup with Gnocchi     266.9
# 85  Dark Chocolate Pumpkin Seed Peanut Brittle     168.1
# 86                 Nicker&rsquo;s Corn Chowder     179.2
#
# [87 rows x 2 columns]
# 이순신 님의 필터된 음식 추천:
# 아침메뉴 추천: 207.20706 kcal 이내
#                                                  Name  Calories
# 0                             Bavarian Cucumber Salad      49.8
# 1                          Buttery Thumbprint Cookies     190.8
# 47                       Pancakes (With Sweet Potato)     185.3
# 48                 Scalloped Green Beans and Tomatoes     118.2
# 49            Linda's Fantabulous Italian Bread a B M      91.7
# 50           Chicken Noodle Soup over Mashed Potatoes     184.7
# 51                                        Lime Pickle     163.5
# 점심메뉴 추천: 883.5291540000001 kcal 이내
#                                        Name  Calories
# 0                              Rolo Cookies     116.7
# 1                    Chocolate Chip Cookies      86.4
# 2                      Snickerdoodles Dream      65.9
# 3                     Best  Praline Cookies     115.4
# 4         Ww Mini Chocolate Chip Cookies Ww      62.8
# ..                                      ...       ...
# 95    Tabouli &amp; Chickpea Couscous Salad     368.7
# 96                          Absolute Heaven      98.4
# 97       Healthy Tuna Salad or Tuna Ceviche     353.7
# 98  Caramelized Onion &amp; Potato Scramble     316.6
# 99      Bran and Flax Bread (Bread Machine)     180.2
#
# [100 rows x 2 columns]
# 저녁메뉴 추천: 294.509718 kcal 이내
#                                                Name  Calories
# 0                                   Margarita Balls      81.2
# 1                           Decorated Spice Cookies      40.3
# 2   Chocolate Oat Bran Cookies With Chocolate Chips      70.1
# 3                             Lemon Crinkle Cookies     143.7
# 4                    Pumpkin Chocolate Chip Cookies     162.7
# ..                                              ...       ...
# 77                     Spiced Apple and Almond Cake     172.3
# 78                   Minestrone - Margaret Fulton's     270.6
# 79                           Sourdough Pumpernickel      82.2
# 80                                     Veal Cutlets     253.5
# 81                     Split Pea With Ham Bone Soup     276.6
#
# [82 rows x 2 columns]
# 신사임당 님의 필터된 음식 추천:
# 아침메뉴 추천: 161.933808 kcal 이내
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 119
#     117 print(user_name, "님의 필터된 음식 추천:")
#     118 print("아침메뉴 추천:", user_info['Calories_threshold']*0.1, "kcal 이내")
# --> 119 recommendations_break = get_recommendations_break(user_info['Keywords'], user_info['TFIDF_matrix'], tfidf_matrix, food, user_info['Calories_threshold'])
#     120 print(pd.DataFrame(recommendations_break[1:100000:1000]))
#     122 print("점심메뉴 추천:", user_info['Calories_threshold']*0.45, "kcal 이내")
#
# Cell In[3], line 68, in get_recommendations_break(user_keywords, user_tfidf_matrix, tfidf_matrix, food_data, calories_threshold)
#      65 recommended_food_break = []
#      67 for index, score in sim_scores:
# ---> 68     food_name = food_data.iloc[index]['Name']
#      69     food_calories = food_data.iloc[index]['Calories']
#      70     if food_calories <= calories_threshold * 0.1:
#
# File E:\jyh\Anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File E:\jyh\Anaconda3\Lib\site-packages\pandas\core\indexing.py:1716, in _iLocIndexer._getitem_axis(self, key, axis)
#    1713 # validate the location
#    1714 self._validate_integer(key, axis)
# -> 1716 return self.obj._ixs(key, axis=axis)
#
# File E:\jyh\Anaconda3\Lib\site-packages\pandas\core\frame.py:3789, in DataFrame._ixs(self, i, axis)
#    3787 # irow
#    3788 if axis == 0:
# -> 3789     new_mgr = self._mgr.fast_xs(i)
#    3791     # if we are a copy, mark as such
#    3792     copy = isinstance(new_mgr.array, np.ndarray) and new_mgr.array.base is None
#
# File E:\jyh\Anaconda3\Lib\site-packages\pandas\core\internals\managers.py:989, in BlockManager.fast_xs(self, loc)
#     987 bp = BlockPlacement(slice(0, len(result)))
#     988 block = new_block(result, placement=bp, ndim=1)
# --> 989 return SingleBlockManager(block, self.axes[0])
#
# KeyboardInterrupt:
